# %%
from __future__ import absolute_import, division, print_function

# %%
#Here We are Importing all the necessary library required for our project.

# %%
import os
import numpy as np
import pandas as pd
import pickle


import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import time

# %matplotlib inline

# %%
#The above basemap library allows us to create map plots.

# %%
# Here we are gonna calculate the  distance between given long/lat
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    #We are now converting the decimal degrees to the radians
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2. * asin(sqrt(a)) 
    r = 6371. #This is the radius of earth
    return c * r

# %%
#The below functions helps us to replace the missing values with the closest possible geographical values.

# %%
def replace_with_nearest(in_df,in_column):

    # Data frame of all the 'NaN's    
    df_nan = in_df[in_df[in_column].isnull()]
    if len(df_nan) > 0:
        # Same date, similar locations
        for i in range(len(df_nan)):
            tmp_date = df_nan['Date'].iloc[i]
            tmp_long = df_nan['Longitude'].iloc[i]
            tmp_lat  = df_nan['Latitude'].iloc[i]
            tmp_index = df_nan['Latitude'].index.tolist()[i]
            condition = (((in_df['Latitude'] != tmp_lat) |
                         (in_df['Longitude'] != tmp_long)) & 
                         (in_df['Date'] == tmp_date) & 
                         (in_df[in_column].notnull())) 
            
            new_df = in_df[['Longitude', 'Latitude']][condition]
            new_df['Distance'] = new_df['Longitude']
            for j in range(len(new_df)):
                new_df['Distance'].iloc[j] = haversine(tmp_long,
                                                       tmp_lat,
                                                       new_df['Longitude'].iloc[j],
                                                       new_df['Latitude'].iloc[j])
            
            tmp_df = new_df.sort_values(by='Distance', ascending=True)
            tmp_min_dist = tmp_df.iloc[0,2]
            tmp_min_index = tmp_df.index.tolist()[0]
            #Here we are replacing the values
            old_val = in_df[in_column].iloc[tmp_index]
            new_val = in_df[in_column].iloc[tmp_min_index]
            in_df[in_column].iloc[tmp_index] = new_val

# %%
#Fetching the data from the given dataset
#Features_101=First Dataset
#Features_102=Second Dataset

# %%
cwd = os.getcwd()
features = os.path.join(cwd,'data','wheat-2013-supervised.csv')
features_101 = pd.read_csv(features)
features_101.head()
# Out:
#   CountyName       State   Latitude   Longitude             Date  \
# 0      Adams  Washington  46.811686 -118.695237  11/30/2013 0:00
# 1      Adams  Washington  46.929839 -118.352109  11/30/2013 0:00
# 2      Adams  Washington  47.006888 -118.510160  11/30/2013 0:00
# 3      Adams  Washington  47.162342 -118.699677  11/30/2013 0:00
# 4      Adams  Washington  47.157512 -118.434056  11/30/2013 0:00
#
#    apparentTemperatureMax  apparentTemperatureMin  cloudCover  dewPoint  \
# 0                   35.70                   20.85        0.00     29.53
# 1                   35.10                   26.92        0.00     29.77
# 2                   33.38                   26.95        0.00     29.36
# 3                   28.05                   25.93        0.91     29.47
# 4                   28.83                   25.98        0.91     29.86
#
#    humidity  ...  precipTypeIsOther  pressure  temperatureMax  temperatureMin  \
# 0      0.91  ...                  0   1027.13           35.70           27.48
# 1      0.93  ...                  0   1026.87           35.10           26.92
# 2      0.94  ...                  0   1026.88           33.38           26.95
# 3      0.94  ...                  0   1026.37           33.19           27.17
# 4      0.94  ...                  0   1026.19           33.85           27.07
#
#    visibility  windBearing  windSpeed        NDVI  DayInSeason  Yield
# 0        2.46          214       1.18  134.110657            0   35.7
# 1        2.83          166       1.01  131.506592            0   35.7
# 2        2.95          158       1.03  131.472946            0   35.7
# 3        2.89          153       1.84  131.288300            0   35.7
# 4        2.97          156       1.85  131.288300            0   35.7
#
# [5 rows x 26 columns]

# %%
cwd = os.getcwd()
features = os.path.join(cwd,'data','wheat-2014-supervised.csv')
features_102 = pd.read_csv(features)
features_102.head()
# Out:
#   CountyName       State   Latitude   Longitude             Date  \
# 0      Adams  Washington  46.929839 -118.352109  11/30/2014 0:00
# 1      Adams  Washington  47.150327 -118.958859  11/30/2014 0:00
# 2      Adams  Washington  46.811686 -118.695237  11/30/2014 0:00
# 3      Adams  Washington  47.162342 -118.699677  11/30/2014 0:00
# 4      Adams  Washington  47.157512 -118.434056  11/30/2014 0:00
#
#    apparentTemperatureMax  apparentTemperatureMin  cloudCover  dewPoint  \
# 0                   18.61                   -3.01        0.00      6.77
# 1                   19.67                   -0.74        0.00      6.66
# 2                   20.66                   -0.14        0.00      6.55
# 3                   19.69                   -2.66        0.03      7.32
# 4                   18.82                   -3.04        0.04      7.62
#
#    humidity  ...  precipTypeIsOther  pressure  temperatureMax  temperatureMin  \
# 0      0.69  ...                  0   1027.95           23.93            6.96
# 1      0.65  ...                  0   1028.26           25.88            8.71
# 2      0.67  ...                  0   1028.29           24.67            8.26
# 3      0.69  ...                  0   1027.74           25.48            8.10
# 4      0.70  ...                  0   1027.16           24.83            8.32
#
#    visibility  windBearing  windSpeed        NDVI  DayInSeason  Yield
# 0       10.00            9       3.80  136.179718            0   35.6
# 1       10.00          352       6.03  135.697540            0   35.6
# 2       10.00           25       3.59  135.676956            0   35.6
# 3       10.00            1       5.18  135.005798            0   35.6
# 4        9.99            5       4.69  134.803864            0   35.6
#
# [5 rows x 26 columns]

# %%
features_101.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177493 entries, 0 to 177492
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CountyName              177493 non-null  object
#  1   State                   177493 non-null  object
#  2   Latitude                177493 non-null  float64
#  3   Longitude               177493 non-null  float64
#  4   Date                    177493 non-null  object
#  5   apparentTemperatureMax  177493 non-null  float64
#  6   apparentTemperatureMin  177493 non-null  float64
#  7   cloudCover              177493 non-null  float64
#  8   dewPoint                177493 non-null  float64
#  9   humidity                177493 non-null  float64
#  10  precipIntensity         177492 non-null  float64
#  11  precipIntensityMax      177492 non-null  float64
#  12  precipProbability       177492 non-null  float64
#  13  precipAccumulation      177493 non-null  float64
#  14  precipTypeIsRain        177493 non-null  int64
#  15  precipTypeIsSnow        177493 non-null  int64
#  16  precipTypeIsOther       177493 non-null  int64
#  17  pressure                177239 non-null  float64
#  18  temperatureMax          177493 non-null  float64
#  19  temperatureMin          177493 non-null  float64
#  20  visibility              177463 non-null  float64
#  21  windBearing             177493 non-null  int64
#  22  windSpeed               177493 non-null  float64
#  23  NDVI                    177493 non-null  float64
#  24  DayInSeason             177493 non-null  int64
#  25  Yield                   177493 non-null  float64
# dtypes: float64(18), int64(5), object(3)
# memory usage: 35.2+ MB

# %%
features_102.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182549 entries, 0 to 182548
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CountyName              182549 non-null  object
#  1   State                   182549 non-null  object
#  2   Latitude                182549 non-null  float64
#  3   Longitude               182549 non-null  float64
#  4   Date                    182549 non-null  object
#  5   apparentTemperatureMax  182549 non-null  float64
#  6   apparentTemperatureMin  182549 non-null  float64
#  7   cloudCover              182549 non-null  float64
#  8   dewPoint                182549 non-null  float64
#  9   humidity                182549 non-null  float64
#  10  precipIntensity         182549 non-null  float64
#  11  precipIntensityMax      182549 non-null  float64
#  12  precipProbability       182549 non-null  float64
#  13  precipAccumulation      182549 non-null  float64
#  14  precipTypeIsRain        182549 non-null  int64
#  15  precipTypeIsSnow        182549 non-null  int64
#  16  precipTypeIsOther       182549 non-null  int64
#  17  pressure                182198 non-null  float64
#  18  temperatureMax          182549 non-null  float64
#  19  temperatureMin          182549 non-null  float64
#  20  visibility              182533 non-null  float64
#  21  windBearing             182549 non-null  int64
#  22  windSpeed               182549 non-null  float64
#  23  NDVI                    182549 non-null  float64
#  24  DayInSeason             182549 non-null  int64
#  25  Yield                   182549 non-null  float64
# dtypes: float64(18), int64(5), object(3)
# memory usage: 36.2+ MB

# %%
#Calculating the total number of null values from the above columns

# %%
features_101.isnull().sum()
# Out:
# CountyName                  0
# State                       0
# Latitude                    0
# Longitude                   0
# Date                        0
# apparentTemperatureMax      0
# apparentTemperatureMin      0
# cloudCover                  0
# dewPoint                    0
# humidity                    0
# precipIntensity             1
# precipIntensityMax          1
# precipProbability           1
# precipAccumulation          0
# precipTypeIsRain            0
# precipTypeIsSnow            0
# precipTypeIsOther           0
# pressure                  254
# temperatureMax              0
# temperatureMin              0
# visibility                 30
# windBearing                 0
# windSpeed                   0
# NDVI                        0
# DayInSeason                 0
# Yield                       0
# dtype: int64

# %%
features_102.isnull().sum()
# Out:
# CountyName                  0
# State                       0
# Latitude                    0
# Longitude                   0
# Date                        0
# apparentTemperatureMax      0
# apparentTemperatureMin      0
# cloudCover                  0
# dewPoint                    0
# humidity                    0
# precipIntensity             0
# precipIntensityMax          0
# precipProbability           0
# precipAccumulation          0
# precipTypeIsRain            0
# precipTypeIsSnow            0
# precipTypeIsOther           0
# pressure                  351
# temperatureMax              0
# temperatureMin              0
# visibility                 16
# windBearing                 0
# windSpeed                   0
# NDVI                        0
# DayInSeason                 0
# Yield                       0
# dtype: int64

# %%
#It can be seen that pressure have the most number of empty values and so does visibility

# %%
#Let's try to convert the date column format to data-time format for more accurate data.
#Upon checking with the data, it was found that it took a lot of time in order to process this files. As a result we have modified few things

# %%
present=time.time()
if not features_101['Date'].dtype==np.dtype('datetime64[ns]'):
    features_101['Date']=features_101['Date'].apply(pd.to_datetime)

# %%
present=time.time()
if not features_102['Date'].dtype==np.dtype('datetime64[ns]'):
    features_102['Date']=features_102['Date'].apply(pd.to_datetime)

# %%
#We will now be using the replace_with_nearest function to replace the missing values with the nearest possible,
#day value
#It Can be observed that the missing values where from the following tables:
#features_101: precipIntensity, precipIntensityMax ,precipProbability ,Pressure & Visibility
#features_102: Pressure, Visibility"

# %%
present = time.time()
replace_with_nearest(features_101, 'precipIntensity')
replace_with_nearest(features_101, 'precipIntensityMax')
replace_with_nearest(features_101, 'precipProbability')
replace_with_nearest(features_101, 'pressure')
replace_with_nearest(features_101, 'visibility')
print('Exec. time: {:5.2f} s'.format(time.time()-present))
# #
# Out:
# Exec. time:  0.01 s

# %%
present = time.time()
replace_with_nearest(features_102, 'pressure')
replace_with_nearest(features_102, 'visibility')
print('Exec. time: {:5.2f} s'.format(time.time()-present))
# Out:
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val
# Exec. time: 30.36 s
# /var/folders/jm/sfhq4l5n1f91q5gjq1cy75q80000gn/T/ipykernel_11056/4253390379.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[in_column].iloc[tmp_index] = new_val

# %%
#Checking if there's any empty/null values present anymore

# %%
features_102.isnull().sum()
# Out:
# CountyName                0
# State                     0
# Latitude                  0
# Longitude                 0
# Date                      0
# apparentTemperatureMax    0
# apparentTemperatureMin    0
# cloudCover                0
# dewPoint                  0
# humidity                  0
# precipIntensity           0
# precipIntensityMax        0
# precipProbability         0
# precipAccumulation        0
# precipTypeIsRain          0
# precipTypeIsSnow          0
# precipTypeIsOther         0
# pressure                  0
# temperatureMax            0
# temperatureMin            0
# visibility                0
# windBearing               0
# windSpeed                 0
# NDVI                      0
# DayInSeason               0
# Yield                     0
# dtype: int64

# %%
features_101.isnull().sum()
# Out:
# CountyName                0
# State                     0
# Latitude                  0
# Longitude                 0
# Date                      0
# apparentTemperatureMax    0
# apparentTemperatureMin    0
# cloudCover                0
# dewPoint                  0
# humidity                  0
# precipIntensity           0
# precipIntensityMax        0
# precipProbability         0
# precipAccumulation        0
# precipTypeIsRain          0
# precipTypeIsSnow          0
# precipTypeIsOther         0
# pressure                  0
# temperatureMax            0
# temperatureMin            0
# visibility                0
# windBearing               0
# windSpeed                 0
# NDVI                      0
# DayInSeason               0
# Yield                     0
# dtype: int64

# %%
#Now we are checking if there's any uncommon column/features among the two datasets.

# %%
totalfeatures_101 = features_101.columns
totalfeatures_102 = features_102.columns
print('Number of features (1st Dataset):', len(totalfeatures_101))
print('Number of features (2nd Dataset):', len(totalfeatures_102))
print('Number of features in common: ', len(set(totalfeatures_101).intersection(totalfeatures_102)))
# Out:
# Number of features (1st Dataset): 26
# Number of features (2nd Dataset): 26
# Number of features in common:  26

# %%
#Now we will be looking for any unique values in each of this features

# %%
features = features_101.columns
for feature in features:
    n_unique_101 = len(features_101[feature].unique())
    n_unique_102 = len(features_102[feature].unique())
    print('{:25} : {:6.0f} {:6.0f}'.format(feature,n_unique_101,n_unique_102))
print('---------------------')
print('Total inspection(1st Dataset): {}'.format(features_101.shape[0]))
print('Total inspection(2nd Dataset): {}'.format(features_102.shape[0]))
# Out:
# CountyName                :    150    156
# State                     :      5      5
# Latitude                  :   1014   1035
# Longitude                 :   1014   1035
# Date                      :    186    186
# apparentTemperatureMax    :  11290   9941
# apparentTemperatureMin    :  10916   9960
# cloudCover                :    101    101
# dewPoint                  :   8909   8331
# humidity                  :     93     86
# precipIntensity           :    661    815
# precipIntensityMax        :   3131   4184
# precipProbability         :     97     98
# precipAccumulation        :   2761   1911
# precipTypeIsRain          :      2      2
# precipTypeIsSnow          :      2      2
# precipTypeIsOther         :      1      1
# pressure                  :   5116   4655
# temperatureMax            :  10408   8323
# temperatureMin            :   9329   8494
# visibility                :    876    899
# windBearing               :    360    360
# windSpeed                 :   2694   2341
# NDVI                      : 125108 129967
# DayInSeason               :    186    186
# Yield                     :    151    137
# ---------------------
# Total inspection(1st Dataset): 177493
# Total inspection(2nd Dataset): 182549

# %%
#It can be seem from the above dataset, that there are more number of county's in 2nd dataset compared with the 1st dataset

# %%
#As there are different county's, let's find there's respective yield count

# %%
ab = features_101.groupby(by='CountyName')
ab_agg = ab.agg({'Yield' : lambda x: len(x.unique())})
diff_counties_101 = ab_agg[ab_agg['Yield'] > 1].index.get_level_values('CountyName').values
ab_agg[ab_agg['Yield'] > 1]
# Out:
#             Yield
# CountyName
# Blaine          2
# Brown           2
# Clay            2
# Comanche        2
# Custer          2
# Douglas         2
# Ellis           3
# Franklin        2
# Garfield        3
# Grant           3
# Gray            2
# Hamilton        2
# Harper          2
# Hill            2
# Jackson         2
# Johnson         2
# Lincoln         2
# Logan           2
# Marshall        2

# %%
ab = features_102.groupby(by='CountyName')
ab_agg = ab.agg({'Yield' : lambda x: len(x.unique())})
diff_counties_102 = ab_agg[ab_agg['Yield'] > 1].index.get_level_values('CountyName').values
ab_agg[ab_agg['Yield'] > 1]
# Out:
#             Yield
# CountyName
# Blaine          2
# Brown           2
# Carter          2
# Comanche        3
# Douglas         2
# Ellis           3
# Franklin        2
# Grant           3
# Hamilton        2
# Harper          2
# Hill            2
# Jackson         2
# Jefferson       2
# Lincoln         2

# %%
#Checking what states do this counties belong to

# %%
print('{} counties in 1st Dataset with more than one yield level.'.format(len(diff_counties_101)))
for idx, diff_county in enumerate(diff_counties_101):
    print('{:10} {}'.format(diff_county, features_101['State'][features_101['CountyName'] == diff_county].unique()))
# Out:
# 19 counties in 1st Dataset with more than one yield level.
# Blaine     ['Montana' 'Oklahoma']
# Brown      ['Kansas' 'Texas']
# Clay       ['Kansas' 'Texas']
# Comanche   ['Kansas' 'Oklahoma']
# Custer     ['Montana' 'Oklahoma']
# Douglas    ['Kansas' 'Washington']
# Ellis      ['Kansas' 'Oklahoma' 'Texas']
# Franklin   ['Kansas' 'Washington']
# Garfield   ['Montana' 'Oklahoma' 'Washington']
# Grant      ['Kansas' 'Oklahoma' 'Washington']
# Gray       ['Kansas' 'Texas']
# Hamilton   ['Kansas' 'Texas']
# Harper     ['Kansas' 'Oklahoma']
# Hill       ['Montana' 'Texas']
# Jackson    ['Kansas' 'Oklahoma']
# Johnson    ['Kansas' 'Texas']
# Lincoln    ['Kansas' 'Washington']
# Logan      ['Kansas' 'Oklahoma']
# Marshall   ['Kansas' 'Oklahoma']

# %%
print('{} counties in 2nd Dataset with more than one yield level.'.format(len(diff_counties_102)))
for idx, diff_county in enumerate(diff_counties_102):
    print('{:10} {}'.format(diff_county, features_102['State'][features_102['CountyName'] == diff_county].unique()))
# Out:
# 14 counties in 2nd Dataset with more than one yield level.
# Blaine     ['Montana' 'Oklahoma']
# Brown      ['Kansas' 'Texas']
# Carter     ['Montana' 'Oklahoma']
# Comanche   ['Kansas' 'Oklahoma' 'Texas']
# Douglas    ['Kansas' 'Washington']
# Ellis      ['Kansas' 'Oklahoma' 'Texas']
# Franklin   ['Kansas' 'Washington']
# Grant      ['Kansas' 'Oklahoma' 'Washington']
# Hamilton   ['Kansas' 'Texas']
# Harper     ['Kansas' 'Oklahoma']
# Hill       ['Montana' 'Texas']
# Jackson    ['Kansas' 'Oklahoma']
# Jefferson  ['Kansas' 'Oklahoma']
# Lincoln    ['Oklahoma' 'Washington']

# %%
#It can be seen that one county can be present in different states, this valid's the fact that there can be mulitple yield values but are found to be completely distinct

# %%
features_101['Location'] = list(zip(features_101['Longitude'], features_101['Latitude']))
features_102['Location'] = list(zip(features_102['Longitude'], features_102['Latitude']))

# %%
#Locations, it can be seen from the above unique values among two different dataset's that we have 1014 and 1035 unique entries in each of this datasets. Let's verify those and check

# %%
#Checking how many of this longittue and latitude are actually in commo

# %%
loc_101 = list(features_101['Location'].unique())
loc_102 = list(features_102['Location'].unique())

# %%
#In order to predict the crop yeild, we will now try to group this dataset's according to there location and check for a new feature, i.e season

# %%
ab_101=features_101.groupby('Location')
ab_102=features_102.groupby('Location')

# %%
ab_101 = ab_101.agg(({'Date' : 'First_Day_in_Season' : np.min},
                           'DayInSeason': {'First_Day_in_Season' : np.min,
                                           'Length_of_Season' : lambda x: np.max(x) - np.min(x)}})
ab_101.head()
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 ab_101 = ab_101.agg({'Date' : {'First_Day_in_Season' : np.min},
#       2                            'DayInSeason': {'First_Day_in_Season' : np.min,
#       3                                            'Length_of_Season' : lambda x: np.max(x) - np.min(x)}})
#       4 ab_101.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/groupby/generic.py:894, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     891 func = maybe_mangle_lambdas(func)
#     893 op = GroupByApply(self, func, args, kwargs)
# --> 894 result = op.agg()
#     895 if not is_dict_like(func) and result is not None:
#     896     return result
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/apply.py:169, in Apply.agg(self)
#     166     return self.apply_str()
#     168 if is_dict_like(arg):
# --> 169     return self.agg_dict_like()
#     170 elif is_list_like(arg):
#     171     # we require a list, but not a 'str'
#     172     return self.agg_list_like()
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/apply.py:478, in Apply.agg_dict_like(self)
#     475     selected_obj = obj._selected_obj
#     476     selection = obj._selection
# --> 478 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     480 if selected_obj.ndim == 1:
#     481     # key only used for output
#     482     colg = obj._gotitem(selection, ndim=1)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/apply.py:594, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     587 # Can't use func.values(); wouldn't work for a Series
#     588 if (
#     589     how == "agg"
#     590     and isinstance(obj, ABCSeries)
#     591     and any(is_list_like(v) for _, v in func.items())
#     592 ) or (any(is_dict_like(v) for _, v in func.items())):
#     593     # GH 15931 - deprecation of renaming keys
# --> 594     raise SpecificationError("nested renamer is not supported")
#     596 if obj.ndim != 1:
#     597     # Check for missing columns on a frame
#     598     cols = set(func.keys()) - set(obj.columns)
#
# SpecificationError: nested renamer is not supported

# %%
ab_101 = ab_101.agg(Date = ('First_Day_in_Season' , np.min)),
                           DayInSeason= ('First_Day_in_Season' , np.min),
                                           ('Length_of_Season' , lambda x: np.max(x) - np.min(x)))
ab_101.head()
# Out:
#   Input In [110]
#     ('Length_of_Season' , lambda x: np.max(x) - np.min(x)))
#                                                           ^
# SyntaxError: positional argument follows keyword argument
